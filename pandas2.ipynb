# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Data/AAPL.csv')

# %%
inf = pd.read_csv('./Data/INFY.csv')
wpr = pd.read_csv('./Data/WIT.csv')

# %%
wpr.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close   Volume
# 0  2018-05-25  4.61  4.63  4.57   4.60       4.60   529500
# 1  2018-05-29  4.56  4.60  4.53   4.56       4.56   718700
# 2  2018-05-30  4.52  4.59  4.50   4.55       4.55   595900
# 3  2018-05-31  4.55  4.61  4.55   4.60       4.60  1440700
# 4  2018-06-01  4.62  4.62  4.59   4.60       4.60   373500

# %%
df = inf.merge(wpr,how='outer',indicator=True)

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  2018-05-25  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
# 1  2018-05-29  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
# 2  2018-05-30  18.059999  18.139999  17.920000  18.139999  17.689873  5033400
# 3  2018-05-31  18.180000  18.309999  18.160000  18.190001  17.738634  5804900
# 4  2018-06-01  18.270000  18.340000  18.219999  18.290001  17.836153  3014500
#
#       _merge
# 0  left_only
# 1  left_only
# 2  left_only
# 3  left_only
# 4  left_only

# %%
df.tail()
# Out:
#           Date  Open  High   Low  Close  Adj Close   Volume      _merge
# 35  2018-06-18  4.85  4.88  4.72   4.83       4.83  1762400  right_only
# 36  2018-06-19  4.75  4.84  4.71   4.80       4.80  1168000  right_only
# 37  2018-06-20  4.71  4.76  4.71   4.74       4.74   602700  right_only
# 38  2018-06-21  4.71  4.78  4.64   4.75       4.75   880400  right_only
# 39  2018-06-22  4.69  4.83  4.69   4.80       4.80  1113700  right_only

# %%
df.rename(columns={'_merge':'STK'},inplace=True)

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  2018-05-25  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
# 1  2018-05-29  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
# 2  2018-05-30  18.059999  18.139999  17.920000  18.139999  17.689873  5033400
# 3  2018-05-31  18.180000  18.309999  18.160000  18.190001  17.738634  5804900
# 4  2018-06-01  18.270000  18.340000  18.219999  18.290001  17.836153  3014500
#
#          STK
# 0  left_only
# 1  left_only
# 2  left_only
# 3  left_only
# 4  left_only

# %%
df.replace(to_replace='left_only' , value = "INF", inplace=True)
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  2018-05-25  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
# 1  2018-05-29  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
# 2  2018-05-30  18.059999  18.139999  17.920000  18.139999  17.689873  5033400
# 3  2018-05-31  18.180000  18.309999  18.160000  18.190001  17.738634  5804900
# 4  2018-06-01  18.270000  18.340000  18.219999  18.290001  17.836153  3014500
#
#    STK
# 0  INF
# 1  INF
# 2  INF
# 3  INF
# 4  INF

# %%
df.tail()
# Out:
#           Date  Open  High   Low  Close  Adj Close   Volume         STK
# 35  2018-06-18  4.85  4.88  4.72   4.83       4.83  1762400  right_only
# 36  2018-06-19  4.75  4.84  4.71   4.80       4.80  1168000  right_only
# 37  2018-06-20  4.71  4.76  4.71   4.74       4.74   602700  right_only
# 38  2018-06-21  4.71  4.78  4.64   4.75       4.75   880400  right_only
# 39  2018-06-22  4.69  4.83  4.69   4.80       4.80  1113700  right_only

# %%
df.replace(to_replace='right_only' , value = "WPR", inplace=True)

# %%
len(df)
# Out:
# 40

# %%
df[::5]
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2018-05-25  18.200001  18.350000  18.160000  18.320000  17.865408
# 5   2018-06-04  18.370001  18.459999  18.350000  18.440001  17.982430
# 10  2018-06-11  18.730000  18.809999  18.639999  18.750000  18.284737
# 15  2018-06-18  18.500000  18.549999  18.410000  18.440001  18.440001
# 20  2018-05-25   4.610000   4.630000   4.570000   4.600000   4.600000
# 25  2018-06-04   4.640000   4.640000   4.570000   4.610000   4.610000
# 30  2018-06-11   4.730000   4.850000   4.710000   4.790000   4.790000
# 35  2018-06-18   4.850000   4.880000   4.720000   4.830000   4.830000
#
#      Volume  STK
# 0   4357800  INF
# 5   2353600  INF
# 10  2573000  INF
# 15  5441600  INF
# 20   529500  WPR
# 25   869300  WPR
# 30  1815600  WPR
# 35  1762400  WPR

# %%
df.index=df['Date']

# %%
df[::5]
# Out:
#                   Date       Open       High        Low      Close  Adj Close  \
# Date
# 2018-05-25  2018-05-25  18.200001  18.350000  18.160000  18.320000  17.865408
# 2018-06-04  2018-06-04  18.370001  18.459999  18.350000  18.440001  17.982430
# 2018-06-11  2018-06-11  18.730000  18.809999  18.639999  18.750000  18.284737
# 2018-06-18  2018-06-18  18.500000  18.549999  18.410000  18.440001  18.440001
# 2018-05-25  2018-05-25   4.610000   4.630000   4.570000   4.600000   4.600000
# 2018-06-04  2018-06-04   4.640000   4.640000   4.570000   4.610000   4.610000
# 2018-06-11  2018-06-11   4.730000   4.850000   4.710000   4.790000   4.790000
# 2018-06-18  2018-06-18   4.850000   4.880000   4.720000   4.830000   4.830000
#
#              Volume  STK
# Date
# 2018-05-25  4357800  INF
# 2018-06-04  2353600  INF
# 2018-06-11  2573000  INF
# 2018-06-18  5441600  INF
# 2018-05-25   529500  WPR
# 2018-06-04   869300  WPR
# 2018-06-11  1815600  WPR
# 2018-06-18  1762400  WPR

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2018-05-25  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
# 2018-05-29  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
# 2018-05-30  18.059999  18.139999  17.920000  18.139999  17.689873  5033400
# 2018-05-31  18.180000  18.309999  18.160000  18.190001  17.738634  5804900
# 2018-06-01  18.270000  18.340000  18.219999  18.290001  17.836153  3014500
# 2018-06-04  18.370001  18.459999  18.350000  18.440001  17.982430  2353600
# 2018-06-05  18.299999  18.389999  18.180000  18.360001  17.904415  3035200
# 2018-06-06  18.459999  18.740000  18.420000  18.740000  18.274984  3208600
# 2018-06-07  18.730000  18.799999  18.559999  18.570000  18.109203  3023800
# 2018-06-08  18.580000  18.799999  18.559999  18.730000  18.265234  3615300
# 2018-06-11  18.730000  18.809999  18.639999  18.750000  18.284737  2573000
# ...

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2018-05-25  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
# 2018-05-29  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
# 2018-05-30  18.059999  18.139999  17.920000  18.139999  17.689873  5033400
# 2018-05-31  18.180000  18.309999  18.160000  18.190001  17.738634  5804900
# 2018-06-01  18.270000  18.340000  18.219999  18.290001  17.836153  3014500
#
#             STK
# Date
# 2018-05-25  INF
# 2018-05-29  INF
# 2018-05-30  INF
# 2018-05-31  INF
# 2018-06-01  INF

# %%
df.sort_index()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2018-05-25  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
# 2018-05-25   4.610000   4.630000   4.570000   4.600000   4.600000   529500
# 2018-05-29  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
# 2018-05-29   4.560000   4.600000   4.530000   4.560000   4.560000   718700
# 2018-05-30  18.059999  18.139999  17.920000  18.139999  17.689873  5033400
# 2018-05-30   4.520000   4.590000   4.500000   4.550000   4.550000   595900
# 2018-05-31  18.180000  18.309999  18.160000  18.190001  17.738634  5804900
# 2018-05-31   4.550000   4.610000   4.550000   4.600000   4.600000  1440700
# 2018-06-01  18.270000  18.340000  18.219999  18.290001  17.836153  3014500
# 2018-06-01   4.620000   4.620000   4.590000   4.600000   4.600000   373500
# 2018-06-04   4.640000   4.640000   4.570000   4.610000   4.610000   869300
# ...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#          Date  STK       Open       High        Low      Close  Adj Close  \
# 0  2018-05-25  INF  18.200001  18.350000  18.160000  18.320000  17.865408
# 1  2018-05-29  INF  18.049999  18.110001  17.879999  18.000000  17.553349
# 2  2018-05-30  INF  18.059999  18.139999  17.920000  18.139999  17.689873
# 3  2018-05-31  INF  18.180000  18.309999  18.160000  18.190001  17.738634
# 4  2018-06-01  INF  18.270000  18.340000  18.219999  18.290001  17.836153
#
#     Volume
# 0  4357800
# 1  6198900
# 2  5033400
# 3  5804900
# 4  3014500

# %%
df.set_index(['Date','STK'],inplace=True)

# %%
df.sort_index(inplace=True)

# %%
inf .              wpr
open high        open high
# Out:
#                      Open       High        Low      Close  Adj Close   Volume
# Date       STK
# 2018-05-25 INF  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
#            WPR   4.610000   4.630000   4.570000   4.600000   4.600000   529500
# 2018-05-29 INF  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
#            WPR   4.560000   4.600000   4.530000   4.560000   4.560000   718700
# 2018-05-30 INF  18.059999  18.139999  17.920000  18.139999  17.689873  5033400
#            WPR   4.520000   4.590000   4.500000   4.550000   4.550000   595900
# 2018-05-31 INF  18.180000  18.309999  18.160000  18.190001  17.738634  5804900
#            WPR   4.550000   4.610000   4.550000   4.600000   4.600000  1440700
# 2018-06-01 INF  18.270000  18.340000  18.219999  18.290001  17.836153  3014500
#            WPR   4.620000   4.620000   4.590000   4.600000   4.600000   373500
# 2018-06-04 INF  18.370001  18.459999  18.350000  18.440001  17.982430  2353600
# ...

# %%
df.unstack()
# Out:
#                  Open             High              Low            Close  \
# STK               INF   WPR        INF   WPR        INF   WPR        INF
# Date
# 2018-05-25  18.200001  4.61  18.350000  4.63  18.160000  4.57  18.320000
# 2018-05-29  18.049999  4.56  18.110001  4.60  17.879999  4.53  18.000000
# 2018-05-30  18.059999  4.52  18.139999  4.59  17.920000  4.50  18.139999
# 2018-05-31  18.180000  4.55  18.309999  4.61  18.160000  4.55  18.190001
# 2018-06-01  18.270000  4.62  18.340000  4.62  18.219999  4.59  18.290001
# 2018-06-04  18.370001  4.64  18.459999  4.64  18.350000  4.57  18.440001
# 2018-06-05  18.299999  4.56  18.389999  4.59  18.180000  4.53  18.360001
# 2018-06-06  18.459999  4.62  18.740000  4.68  18.420000  4.59  18.740000
# 2018-06-07  18.730000  4.61  18.799999  4.72  18.559999  4.61  18.570000
# 2018-06-08  18.580000  4.68  18.799999  4.73  18.559999  4.64  18.730000
# 2018-06-11  18.730000  4.73  18.809999  4.85  18.639999  4.71  18.750000
# ...

# %%
df.head()
# Out:
#                      Open       High        Low      Close  Adj Close   Volume
# Date       STK
# 2018-05-25 INF  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
#            WPR   4.610000   4.630000   4.570000   4.600000   4.600000   529500
# 2018-05-29 INF  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
#            WPR   4.560000   4.600000   4.530000   4.560000   4.560000   718700
# 2018-05-30 INF  18.059999  18.139999  17.920000  18.139999  17.689873  5033400

# %%
import matplotlib.pyplot as plt

# %%
df.unstack().plot(y='Close',kind='bar')
plt.show()

# %%
df.head()
# Out:
#                      Open       High        Low      Close  Adj Close   Volume
# Date       STK
# 2018-05-25 INF  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
#            WPR   4.610000   4.630000   4.570000   4.600000   4.600000   529500
# 2018-05-29 INF  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
#            WPR   4.560000   4.600000   4.530000   4.560000   4.560000   718700
# 2018-05-30 INF  18.059999  18.139999  17.920000  18.139999  17.689873  5033400

# %%
df.head()
# Out:
#                      Open       High        Low      Close  Adj Close   Volume
# Date       STK
# 2018-05-25 INF  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
#            WPR   4.610000   4.630000   4.570000   4.600000   4.600000   529500
# 2018-05-29 INF  18.049999  18.110001  17.879999  18.000000  17.553349  6198900
#            WPR   4.560000   4.600000   4.530000   4.560000   4.560000   718700
# 2018-05-30 INF  18.059999  18.139999  17.920000  18.139999  17.689873  5033400

# %%
df.loc['2018-05-25']
# Out:
#           Open   High    Low  Close  Adj Close   Volume
# STK
# INF  18.200001  18.35  18.16  18.32  17.865408  4357800
# WPR   4.610000   4.63   4.57   4.60   4.600000   529500

# %%
df.loc[('2018-05-25','INF')]
# Out:
# Open         1.820000e+01
# High         1.835000e+01
# Low          1.816000e+01
# Close        1.832000e+01
# Adj Close    1.786541e+01
# Volume       4.357800e+06
# Name: (2018-05-25, INF), dtype: float64

# %%
df.loc[('2018-05-25','WPR'),'High':]
# Out:
# High              4.63
# Low               4.57
# Close             4.60
# Adj Close         4.60
# Volume       529500.00
# Name: (2018-05-25, WPR), dtype: float64

# %%
df.loc['2018-05-25':'2018-05-30','High':]
# Out:
#                      High        Low      Close  Adj Close   Volume
# Date       STK
# 2018-05-25 INF  18.350000  18.160000  18.320000  17.865408  4357800
#            WPR   4.630000   4.570000   4.600000   4.600000   529500
# 2018-05-29 INF  18.110001  17.879999  18.000000  17.553349  6198900
#            WPR   4.600000   4.530000   4.560000   4.560000   718700
# 2018-05-30 INF  18.139999  17.920000  18.139999  17.689873  5033400
#            WPR   4.590000   4.500000   4.550000   4.550000   595900

# %%
df.loc[ (slice(None), 'WPR'),:]
# Out:
#                 Open  High   Low  Close  Adj Close   Volume
# Date       STK
# 2018-05-25 WPR  4.61  4.63  4.57   4.60       4.60   529500
# 2018-05-29 WPR  4.56  4.60  4.53   4.56       4.56   718700
# 2018-05-30 WPR  4.52  4.59  4.50   4.55       4.55   595900
# 2018-05-31 WPR  4.55  4.61  4.55   4.60       4.60  1440700
# 2018-06-01 WPR  4.62  4.62  4.59   4.60       4.60   373500
# 2018-06-04 WPR  4.64  4.64  4.57   4.61       4.61   869300
# 2018-06-05 WPR  4.56  4.59  4.53   4.55       4.55   806200
# 2018-06-06 WPR  4.62  4.68  4.59   4.65       4.65   537200
# 2018-06-07 WPR  4.61  4.72  4.61   4.70       4.70   897300
# 2018-06-08 WPR  4.68  4.73  4.64   4.72       4.72   652600
# 2018-06-11 WPR  4.73  4.85  4.71   4.79       4.79  1815600
# 2018-06-12 WPR  4.76  4.92  4.76   4.92       4.92  1016700
# 2018-06-13 WPR  4.92  4.92  4.83   4.89       4.89  1486800
# 2018-06-14 WPR  4.86  4.86  4.73   4.76       4.76  1452900
# ...

# %%
df.loc[ (slice('2018-05-25','2018-06-22',2), 'INF'),:]
# Out:
#                      Open       High        Low      Close  Adj Close   Volume
# Date       STK
# 2018-05-25 INF  18.200001  18.350000  18.160000  18.320000  17.865408  4357800
# 2018-05-30 INF  18.059999  18.139999  17.920000  18.139999  17.689873  5033400
# 2018-06-01 INF  18.270000  18.340000  18.219999  18.290001  17.836153  3014500
# 2018-06-05 INF  18.299999  18.389999  18.180000  18.360001  17.904415  3035200
# 2018-06-07 INF  18.730000  18.799999  18.559999  18.570000  18.109203  3023800
# 2018-06-11 INF  18.730000  18.809999  18.639999  18.750000  18.284737  2573000
# 2018-06-13 INF  19.000000  19.100000  18.809999  18.820000  18.353001  4798800
# 2018-06-15 INF  18.590000  18.770000  18.559999  18.730000  18.730000  5640200
# 2018-06-19 INF  18.299999  18.299999  18.150000  18.200001  18.200001  7693500
# 2018-06-21 INF  18.230000  18.270000  18.160000  18.230000  18.230000  3727800

# %%
slice(10,10,1)
# Out:
# slice(10, 10, 1)
