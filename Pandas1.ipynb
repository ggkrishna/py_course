# %% [markdown]
# # What is pandas?
# + Python library for data analysis
# + High-performance containers for data analysis
# + Data structures with a lot of functionality
# + Meaningful labels
# + Time series functionality Handling missing data
# + Relational operations

# %% [markdown]
# ## Three main data structures of Pandas
#
# + Series
#
# + Data Frames
#
# + Data Panels

# %%
import pandas as pd   # pd aliasing is convention

# %% [markdown]
# ## Loading the csv file data into a pandas DataFrame.

# %%
df = pd.read_csv('./Data/AAPL.csv')  # try to explore several options of read_csv

# %%
#pd.read_csv()  #explore how many types of files formats pandas can read

# %%
# printing first five rows of the data frame
#df.head()  # 5 is the default value. we can ask for any number as shown below
df.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4  2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
# 5  2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 6  2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 7  2018-05-31  187.220001  188.229996  186.139999  186.869995  186.869995
# 8  2018-06-01  187.990005  190.259995  187.750000  190.240005  190.240005
# 9  2018-06-04  191.639999  193.419998  191.350006  191.830002  191.830002
#
#      Volume
# 0  18400800
# 1  15240700
# 2  19467900
# 3  20401000
# 4  17461000
# 5  22369000
# 6  18690500
# 7  27482800
# 8  23250400
# 9  26132000

# %% [markdown]
# ### Above we get to see all the data of the csv file are neatly arranged in a tabular format called data frame.
# ### Each row of data is associated with an index. Here the indices are automatically generated integers starting from zero.

# %%
# display specific number of rows from bottom of the file 5 is the default 
df.tail(8)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 13  2018-06-08  191.169998  192.000000  189.770004  191.699997  191.699997
# 14  2018-06-11  191.350006  191.970001  190.210007  191.229996  191.229996
# 15  2018-06-12  191.389999  192.610001  191.149994  192.279999  192.279999
# 16  2018-06-13  192.419998  192.880005  190.440002  190.699997  190.699997
# 17  2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 18  2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
# 19  2018-06-18  187.880005  189.220001  187.199997  188.740005  188.740005
# 20  2018-06-19  185.139999  186.330002  183.449997  185.690002  185.690002
#
#       Volume
# 13  26656800
# 14  18308500
# 15  16911100
# 16  21638400
# 17  21610100
# 18  61719200
# 19  18484900
# 20  32502500

# %%
# How the python builtin type function interprets the object df?
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns    # what are all te
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# reading csv file with first column as index 

df = pd.read_csv('./Data/AAPL.csv', index_col=0)

# Here we have dates as the index unlike numbers starting from zero as in previous case
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %% [markdown]
# ### Some pandas data frame attributes and methods

# %%
df.index
# Out:
# Index(['2018-05-21', '2018-05-22', '2018-05-23', '2018-05-24', '2018-05-25',
#        '2018-05-29', '2018-05-30', '2018-05-31', '2018-06-01', '2018-06-04',
#        '2018-06-05', '2018-06-06', '2018-06-07', '2018-06-08', '2018-06-11',
#        '2018-06-12', '2018-06-13', '2018-06-14', '2018-06-15', '2018-06-18',
#        '2018-06-19'],
#       dtype='object', name='Date')

# %%
# how many rows and columns?
df.shape
# Out:
# (21, 6)

# %%
# summary of information about the data frame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 2018-05-21 to 2018-06-19
# Data columns (total 6 columns):
# Open         21 non-null float64
# High         21 non-null float64
# Low          21 non-null float64
# Close        21 non-null float64
# Adj Close    21 non-null float64
# Volume       21 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 1.1+ KB

# %%
# statistical information related to the data frame
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count   21.000000   21.000000   21.000000   21.000000   21.000000
# mean   189.698573  190.607620  188.548571  189.759524  189.759524
# std      2.543028    2.319233    2.506535    2.402797    2.402797
# min    185.139999  186.330002  183.449997  185.690002  185.690002
# 25%    187.880005  188.839996  186.779999  187.899994  187.899994
# 50%    188.770004  190.160004  187.750000  188.839996  188.839996
# 75%    191.550003  192.610001  190.440002  191.699997  191.699997
# max    194.139999  194.199997  192.360001  193.979996  193.979996
#
#              Volume
# count  2.100000e+01
# mean   2.336069e+07
# std    9.676355e+06
# min    1.524070e+07
# 25%    1.848490e+07
# 50%    2.134720e+07
# 75%    2.325040e+07
# max    6.171920e+07

# %% [markdown]
# ### Accessing Columns

# %%
# Each column can be accessed with the column name as shown below 
# We use squre brackets just like a pyton List

df_open = df['Open']
print(df_open)
# Out:
# Date
# 2018-05-21    188.000000
# 2018-05-22    188.380005
# 2018-05-23    186.350006
# 2018-05-24    188.770004
# 2018-05-25    188.229996
# 2018-05-29    187.600006
# 2018-05-30    187.720001
# 2018-05-31    187.220001
# 2018-06-01    187.990005
# 2018-06-04    191.639999
# 2018-06-05    193.070007
# 2018-06-06    193.630005
# 2018-06-07    194.139999
# 2018-06-08    191.169998
# 2018-06-11    191.350006
# 2018-06-12    191.389999
# 2018-06-13    192.419998
# 2018-06-14    191.550003
# 2018-06-15    190.029999
# 2018-06-18    187.880005
# 2018-06-19    185.139999
# Name: Open, dtype: float64

# %%
# what is that returned? 
type(df_open)  # it is a Pandas Series
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Series is just like a list associated with index

# %%
# we can even access multiple columns of a data frame

# %%
df['Open','Close']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: ('Open', 'Close')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-c1216055b2b5> in <module>()
# ----> 1 df['Open','Close']
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: ('Open', 'Close')

# %%
df[['Open','Close']]  # we need to pass the list of columns that we want access. Not just the individual column names 
                      # try without extra squre bracket
# Out:
#                   Open       Close
# Date
# 2018-05-21  188.000000  187.630005
# 2018-05-22  188.380005  187.160004
# 2018-05-23  186.350006  188.360001
# 2018-05-24  188.770004  188.149994
# 2018-05-25  188.229996  188.580002
# 2018-05-29  187.600006  187.899994
# 2018-05-30  187.720001  187.500000
# 2018-05-31  187.220001  186.869995
# 2018-06-01  187.990005  190.240005
# 2018-06-04  191.639999  191.830002
# 2018-06-05  193.070007  193.309998
# 2018-06-06  193.630005  193.979996
# 2018-06-07  194.139999  193.460007
# 2018-06-08  191.169998  191.699997
# 2018-06-11  191.350006  191.229996
# 2018-06-12  191.389999  192.279999
# 2018-06-13  192.419998  190.699997
# 2018-06-14  191.550003  190.800003
# 2018-06-15  190.029999  188.839996
# 2018-06-18  187.880005  188.740005
# 2018-06-19  185.139999  185.690002

# %%
# try without extra squre bracket

# %%
type(df[['Open','Close']] )   # This retuns us a Data Frame as we tried to access more than one column
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Close','Open']]   # Observe the change of order in column names
# Out:
#                  Close        Open
# Date
# 2018-05-21  187.630005  188.000000
# 2018-05-22  187.160004  188.380005
# 2018-05-23  188.360001  186.350006
# 2018-05-24  188.149994  188.770004
# 2018-05-25  188.580002  188.229996
# 2018-05-29  187.899994  187.600006
# 2018-05-30  187.500000  187.720001
# 2018-05-31  186.869995  187.220001
# 2018-06-01  190.240005  187.990005
# 2018-06-04  191.830002  191.639999
# 2018-06-05  193.309998  193.070007
# 2018-06-06  193.979996  193.630005
# 2018-06-07  193.460007  194.139999
# 2018-06-08  191.699997  191.169998
# 2018-06-11  191.229996  191.350006
# 2018-06-12  192.279999  191.389999
# 2018-06-13  190.699997  192.419998
# 2018-06-14  190.800003  191.550003
# 2018-06-15  188.839996  190.029999
# 2018-06-18  188.740005  187.880005
# 2018-06-19  185.690002  185.139999

# %% [markdown]
# ## Accessing Rows

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %%
df['2018-05-21'] # Try to understand the error ... Its searching in columns !!! 
                 # its reserved for columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: '2018-05-21'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-3622f47767f5> in <module>()
# ----> 1 df['2018-05-21'] # Try to understand the error ... Its searching in columns !!!
#       2                  # its reserved for columns
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: '2018-05-21'

# %% [markdown]
# ## Slicing rows

# %%
df['2018-05-21':'2018-05-29']    # but we can give range of index values and access the corresponding rows
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000
# 2018-05-29  22369000

# %% [markdown]
# ### Observe the capabaility of date time interpretation by pandas

# %%
df['2018-05-21':'2018-05-28']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %% [markdown]
# ### How to access a single row?

# %%
df['2018-05-21':'2018-05-21']  # But it returns not a series but a data frame
# Out:
#              Open        High         Low       Close   Adj Close    Volume
# Date
# 2018-05-21  188.0  189.270004  186.910004  187.630005  187.630005  18400800

# %%
type(df['2018-05-21':'2018-05-21'])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### What the Open share value on 2018-05-25 ? How do we get it?

# %%
df['Open']['2018-05-25']    # try some more
# Out:
# 188.229996

# %% [markdown]
# ## Accessors
# ###   .loc  &nbsp;&nbsp;&nbsp;&nbsp;  - Uses Labels
# ###  .iloc   &nbsp;&nbsp;&nbsp;&nbsp;    - Uses Locations

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %%
df.loc['2018-05-21']
# Out:
# Open         1.880000e+02
# High         1.892700e+02
# Low          1.869100e+02
# Close        1.876300e+02
# Adj Close    1.876300e+02
# Volume       1.840080e+07
# Name: 2018-05-21, dtype: float64

# %%
df.loc['2018-05-21','Open']
# Out:
# 188.0

# %%
df.loc['2018-05-21',['Open','Volume']]
# Out:
# Open           188.0
# Volume    18400800.0
# Name: 2018-05-21, dtype: float64

# %%
df.loc[['2018-05-21','2018-05-25'],['Open','Volume']]
# Out:
#                   Open    Volume
# Date
# 2018-05-21  188.000000  18400800
# 2018-05-25  188.229996  17461000

# %%
df.loc['2018-05-30'::2,['Open','Volume']]   # What is that we are trying to do here?
# Out:
#                   Open    Volume
# Date
# 2018-05-30  187.720001  18690500
# 2018-06-01  187.990005  23250400
# 2018-06-05  193.070007  21566000
# 2018-06-07  194.139999  21347200
# 2018-06-11  191.350006  18308500
# 2018-06-13  192.419998  21638400
# 2018-06-15  190.029999  61719200
# 2018-06-19  185.139999  32502500

# %%
df.iloc[0,0]   # returns element of first row and first column as per zero indexing
# Out:
# 188.0

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %%
df.iloc[1,2:3]   # What it returned?
# Out:
# Low    186.779999
# Name: 2018-05-22, dtype: float64

# %% [markdown]
# ## Filtering

# %%
df['Open']<187   # It returns a boolean series
# Out:
# Date
# 2018-05-21    False
# 2018-05-22    False
# 2018-05-23     True
# 2018-05-24    False
# 2018-05-25    False
# 2018-05-29    False
# 2018-05-30    False
# 2018-05-31    False
# 2018-06-01    False
# 2018-06-04    False
# 2018-06-05    False
# 2018-06-06    False
# 2018-06-07    False
# 2018-06-08    False
# 2018-06-11    False
# 2018-06-12    False
# 2018-06-13    False
# 2018-06-14    False
# 2018-06-15    False
# 2018-06-18    False
# 2018-06-19     True
# Name: Open, dtype: bool

# %%
df[df['Open']<187]  # retunrs a data frame with he rows tht a has OPen<187
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-06-19  185.139999  186.330002  183.449997  185.690002  185.690002
#
#               Volume
# Date
# 2018-05-23  19467900
# 2018-06-19  32502500

# %%
# What are the days Apple stocks shown some improvement?

# %%
df[(df['High']-df['Low'])<2]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 2018-06-05  193.070007  193.940002  192.360001  193.309998  193.309998
# 2018-06-07  194.139999  194.199997  192.339996  193.460007  193.460007
# 2018-06-11  191.350006  191.970001  190.210007  191.229996  191.229996
# 2018-06-12  191.389999  192.610001  191.149994  192.279999  192.279999
# 2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
#
#               Volume
# Date
# 2018-05-29  22369000
# 2018-05-30  18690500
# 2018-06-05  21566000
# 2018-06-07  21347200
# 2018-06-11  18308500
# 2018-06-12  16911100
# 2018-06-14  21610100
# 2018-06-15  61719200

# %%
df[df['Close']>df['Open']][['Open','Close']]
# Out:
#                   Open       Close
# Date
# 2018-05-23  186.350006  188.360001
# 2018-05-25  188.229996  188.580002
# 2018-05-29  187.600006  187.899994
# 2018-06-01  187.990005  190.240005
# 2018-06-04  191.639999  191.830002
# 2018-06-05  193.070007  193.309998
# 2018-06-06  193.630005  193.979996
# 2018-06-08  191.169998  191.699997
# 2018-06-12  191.389999  192.279999
# 2018-06-18  187.880005  188.740005
# 2018-06-19  185.139999  185.690002

# %%
# What are the days Apple stocks didnt fluctuate much?

# %% [markdown]
# ### Combining filters

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %%
# What are the days Apple stocks opened nearly at high and closed nearly at low

# %%
df[(abs(df['Open']-df['High'])<0.5 ) & (abs(df['Close']-df['Low'])<0.5)]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-06-13  192.419998  192.880005  190.440002  190.699997  190.699997
#
#               Volume
# Date
# 2018-06-13  21638400

# %%
(abs(df['Open']-df['High'])<0.5 ) & (abs(df['Close']-df['Low'])<0.5)
# Out:
# Date
# 2018-05-21    False
# 2018-05-22    False
# 2018-05-23    False
# 2018-05-24    False
# 2018-05-25    False
# 2018-05-29    False
# 2018-05-30    False
# 2018-05-31    False
# 2018-06-01    False
# 2018-06-04    False
# 2018-06-05    False
# 2018-06-06    False
# 2018-06-07    False
# 2018-06-08    False
# 2018-06-11    False
# 2018-06-12    False
# 2018-06-13     True
# 2018-06-14    False
# 2018-06-15    False
# 2018-06-18    False
# 2018-06-19    False
# dtype: bool

# %%
# either it opend at high are closed at low

df[(abs(df['Open']-df['High'])<0.2 ) | (abs(df['Close']-df['Low'])<0.2)]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-06-07  194.139999  194.199997  192.339996  193.460007  193.460007
# 2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
#
#               Volume
# Date
# 2018-05-24  20401000
# 2018-06-07  21347200
# 2018-06-14  21610100
# 2018-06-15  61719200

# %% [markdown]
# ### checking non null values

# %%
df.all()  # checks if all the elements in each column are non-null
# Out:
# Open         True
# High         True
# Low          True
# Close        True
# Adj Close    True
# Volume       True
# dtype: bool

# %%
df.all(axis=1)
# Out:
# Date
# 2018-05-21    True
# 2018-05-22    True
# 2018-05-23    True
# 2018-05-24    True
# 2018-05-25    True
# 2018-05-29    True
# 2018-05-30    True
# 2018-05-31    True
# 2018-06-01    True
# 2018-06-04    True
# 2018-06-05    True
# 2018-06-06    True
# 2018-06-07    True
# 2018-06-08    True
# 2018-06-11    True
# 2018-06-12    True
# 2018-06-13    True
# 2018-06-14    True
# 2018-06-15    True
# 2018-06-18    True
# 2018-06-19    True
# dtype: bool

# %%
# copy 
df2=df
print(id(df),sep='\n')
print(id(df2),sep='\n')
# Out:
# 4545896288
# 4545896288

# %%
# Deep copy 
df2=df.copy()
print(id(df),sep='\n')
print(id(df2),sep='\n')
# Out:
# 4545896288
# 4545882040

# %%
df2['zeros']=0  # created a column of zeros with zero values
df2.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume  zeros
# Date
# 2018-05-21  18400800      0
# 2018-05-22  15240700      0
# 2018-05-23  19467900      0
# 2018-05-24  20401000      0
# 2018-05-25  17461000      0

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %%
df2.all()
# Out:
# Open          True
# High          True
# Low           True
# Close         True
# Adj Close     True
# Volume        True
# zeros        False
# dtype: bool

# %%
df2.all(axis=1)
# Out:
# Date
# 2018-05-21    False
# 2018-05-22    False
# 2018-05-23    False
# 2018-05-24    False
# 2018-05-25    False
# 2018-05-29    False
# 2018-05-30    False
# 2018-05-31    False
# 2018-06-01    False
# 2018-06-04    False
# 2018-06-05    False
# 2018-06-06    False
# 2018-06-07    False
# 2018-06-08    False
# 2018-06-11    False
# 2018-06-12    False
# 2018-06-13    False
# 2018-06-14    False
# 2018-06-15    False
# 2018-06-18    False
# 2018-06-19    False
# dtype: bool

# %%
df2.any()
# Out:
# Open          True
# High          True
# Low           True
# Close         True
# Adj Close     True
# Volume        True
# zeros        False
# dtype: bool

# %%
df2.any(axis=1)
# Out:
# Date
# 2018-05-21    True
# 2018-05-22    True
# 2018-05-23    True
# 2018-05-24    True
# 2018-05-25    True
# 2018-05-29    True
# 2018-05-30    True
# 2018-05-31    True
# 2018-06-01    True
# 2018-06-04    True
# 2018-06-05    True
# 2018-06-06    True
# 2018-06-07    True
# 2018-06-08    True
# 2018-06-11    True
# 2018-06-12    True
# 2018-06-13    True
# 2018-06-14    True
# 2018-06-15    True
# 2018-06-18    True
# 2018-06-19    True
# dtype: bool

# %%
df2.loc[:,df2.any()]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 2018-05-31  187.220001  188.229996  186.139999  186.869995  186.869995
# 2018-06-01  187.990005  190.259995  187.750000  190.240005  190.240005
# 2018-06-04  191.639999  193.419998  191.350006  191.830002  191.830002
# 2018-06-05  193.070007  193.940002  192.360001  193.309998  193.309998
# 2018-06-06  193.630005  194.080002  191.919998  193.979996  193.979996
# 2018-06-07  194.139999  194.199997  192.339996  193.460007  193.460007
# 2018-06-08  191.169998  192.000000  189.770004  191.699997  191.699997
# 2018-06-11  191.350006  191.970001  190.210007  191.229996  191.229996
# 2018-06-12  191.389999  192.610001  191.149994  192.279999  192.279999
# 2018-06-13  192.419998  192.880005  190.440002  190.699997  190.699997
# 2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
# 2018-06-18  187.880005  189.220001  187.199997  188.740005  188.740005
# 2018-06-19  185.139999  186.330002  183.449997  185.690002  185.690002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000
# 2018-05-29  22369000
# 2018-05-30  18690500
# 2018-05-31  27482800
# 2018-06-01  23250400
# 2018-06-04  26132000
# 2018-06-05  21566000
# 2018-06-06  20933600
# 2018-06-07  21347200
# 2018-06-08  26656800
# 2018-06-11  18308500
# 2018-06-12  16911100
# 2018-06-13  21638400
# 2018-06-14  21610100
# 2018-06-15  61719200
# 2018-06-18  18484900
# 2018-06-19  32502500

# %%
import numpy as np

# %%
df2.iloc[4,3]=np.nan

# %%
df2.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994         NaN  188.580002
#
#               Volume  zeros
# Date
# 2018-05-21  18400800      0
# 2018-05-22  15240700      0
# 2018-05-23  19467900      0
# 2018-05-24  20401000      0
# 2018-05-25  17461000      0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 2018-05-21 to 2018-06-19
# Data columns (total 7 columns):
# Open         21 non-null float64
# High         21 non-null float64
# Low          21 non-null float64
# Close        20 non-null float64
# Adj Close    21 non-null float64
# Volume       21 non-null int64
# zeros        21 non-null int64
# dtypes: float64(5), int64(2)
# memory usage: 1.9+ KB

# %%
df2.dropna(inplace=True)

# %%
df2.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-29  22369000

# %%
df2.drop('zeros',axis=1,inplace=True)  # dropping a particular column thats not required

# %%
df2.head()  # what the above did is just returned an object after dropping but change in actual object didn't take place
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-29  22369000

# %%
# Try to delete 'Adj Close' Column

# %%
df2.drop('Adj Close', axis=1,inplace=True)

# %%
df2.head(8)
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  18400800
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  15240700
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  19467900
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  20401000
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  22369000
# 2018-05-30  187.720001  188.000000  186.779999  187.500000  18690500
# 2018-05-31  187.220001  188.229996  186.139999  186.869995  27482800
# 2018-06-01  187.990005  190.259995  187.750000  190.240005  23250400

# %% [markdown]
# #### Create another column 'Change'

# %%
df2['Change']=df2['Open']-df2['Close']

# %%
df2.head()
# Out:
#                   Open        High         Low       Close    Volume    Change
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  18400800  0.369995
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  15240700  1.220001
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  19467900 -2.009995
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  20401000  0.620010
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  22369000 -0.299988

# %%
# The volume number are huge compared to others. Scale them

# %%
df2['Volume']/=100000   # this could be possible because they are internally numpy arrays

# %%
df2.head()
# Out:
#                   Open        High         Low       Close   Volume    Change
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  184.008  0.369995
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  152.407  1.220001
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  194.679 -2.009995
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  204.010  0.620010
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  223.690 -0.299988

# %%
# Even any other numpy unversal function can be applied 

df2['Change'].abs()
# Out:
# Date
# 2018-05-21    0.369995
# 2018-05-22    1.220001
# 2018-05-23    2.009995
# 2018-05-24    0.620010
# 2018-05-29    0.299988
# 2018-05-30    0.220001
# 2018-05-31    0.350006
# 2018-06-01    2.250000
# 2018-06-04    0.190003
# 2018-06-05    0.239991
# 2018-06-06    0.349991
# 2018-06-07    0.679992
# 2018-06-08    0.529999
# 2018-06-11    0.120010
# 2018-06-12    0.890000
# 2018-06-13    1.720001
# 2018-06-14    0.750000
# 2018-06-15    1.190003
# 2018-06-18    0.860000
# 2018-06-19    0.550003
# Name: Change, dtype: float64

# %%
# abs is actually a numpy function so it can also be implemented as follows
np.abs(df2['Change'])
# Out:
# Date
# 2018-05-21    0.369995
# 2018-05-22    1.220001
# 2018-05-23    2.009995
# 2018-05-24    0.620010
# 2018-05-25         NaN
# 2018-05-29         NaN
# 2018-05-30    0.220001
# 2018-05-31    0.350006
# 2018-06-01    2.250000
# 2018-06-04    0.190003
# 2018-06-05    0.239991
# 2018-06-06    0.349991
# 2018-06-07    0.679992
# 2018-06-08    0.529999
# 2018-06-11    0.120010
# 2018-06-12    0.890000
# 2018-06-13    1.720001
# 2018-06-14    0.750000
# 2018-06-15    1.190003
# 2018-06-18    0.860000
# 2018-06-19    0.550003
# Name: Change, dtype: float64

# %% [markdown]
# ### Apply()

# %%
def qnt(x):
    return (x*2)/3

# %%
qnt(100)   # it accepts just a scalar i.e a single value as an argument
# Out:
# 66.66666666666667

# %% [markdown]
# ### How to use it for all the elements of data frame?

# %%
df2=df2.apply(qnt)

# %%
df2['Open'].apply(qnt)
# Out:
# Date
# 2018-05-21    125.333333
# 2018-05-22    125.586670
# 2018-05-23    124.233337
# 2018-05-24    125.846669
# 2018-05-29    125.066671
# 2018-05-30    125.146667
# 2018-05-31    124.813334
# 2018-06-01    125.326670
# 2018-06-04    127.759999
# 2018-06-05    128.713338
# 2018-06-06    129.086670
# 2018-06-07    129.426666
# 2018-06-08    127.446665
# 2018-06-11    127.566671
# 2018-06-12    127.593333
# 2018-06-13    128.279999
# 2018-06-14    127.700002
# 2018-06-15    126.686666
# 2018-06-18    125.253337
# 2018-06-19    123.426666
# Name: Open, dtype: float64

# %%
def lm(x):
    return x/2

# %%
df2['Open'].apply(lambda x:2*x/32)
# Out:
# Date
# 2018-05-21    62.666667
# 2018-05-22    62.793335
# 2018-05-23    62.116669
# 2018-05-24    62.923335
# 2018-05-29    62.533335
# 2018-05-30    62.573334
# 2018-05-31    62.406667
# 2018-06-01    62.663335
# 2018-06-04    63.880000
# 2018-06-05    64.356669
# 2018-06-06    64.543335
# 2018-06-07    64.713333
# 2018-06-08    63.723333
# 2018-06-11    63.783335
# 2018-06-12    63.796666
# 2018-06-13    64.139999
# 2018-06-14    63.850001
# 2018-06-15    63.343333
# 2018-06-18    62.626668
# 2018-06-19    61.713333
# Name: Open, dtype: float64

# %% [markdown]
# ## Saving the changes into a file

# %%
df2.to_csv('./Data/changes.csv')

# %%
df2.to_excel('./Data/chg.xls')
